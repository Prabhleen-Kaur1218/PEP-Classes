# %% [markdown]
# # Exceptional handling

# %%
a =10
b= 0
try:
    d =a/b
    print(d)
    print('inside try')

except ZeroDivisionError:
    print("Division by zero is not allowed")

else:
    print("inside else")

finally:
    print("inside finally")

print('rest of the code')
# Out:
# Division by zero is not allowed
# inside finally
# rest of the code

# %%
a = 10
b = 0
try:
    d= a/g
    print(d)

except ZeroDivisionError:
    print("Dicivion errpr is not allowed")

except NameError:
    print("correct the name")
# Out:
# correct the name
