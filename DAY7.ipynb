# %% [markdown]
# # Working with file paths

# %%
import os
cwd=os.getcwd()
print(f"Current working directory is {cwd}")
# Out:
# Current working directory is c:\Users\ACER\Desktop\python

# %%
#creating new_directory
new_directory="package"
os.mkdir(new_directory)
print(f"Directory'{new_directory}' create")
# Out:
# Directory'package' create

# %%
#listing files
items=os.listdir('.')
print(items)
# Out:
# ['class.ipynb', 'filepaths.ipynb', 'function.ipynb', 'list.ipynb', 'new_directory', 'oops.ipynb', 'package', 'tempCodeRunnerFile.ipynb']

# %% [markdown]
# # Read and Write Files

# %%
f = open("package/hello.txt", "w")
